# %%
import pandas as pd
from fpgrowth import fpgrowth
from util import association_rules

# %%
odf = pd.read_csv("../../data/ibm.csv")
df = odf.groupby(['transaction_id']).item_id.apply(tuple).reset_index(name='item')
df["length"] = df.item.apply(lambda x: len(x))
df
# Out:
#      transaction_id                                    item  length
# 0                 1               (307, 443, 470, 723, 973)       5
# 1                 2  (3, 111, 451, 487, 488, 523, 647, 764)       8
# 2                 3                              (595, 764)       2
# 3                 4            (3, 111, 451, 487, 488, 523)       6
# 4                 5               (307, 443, 470, 723, 973)       5
# ..              ...                                     ...     ...
# 823             824                         (402, 705, 961)       3
# 824             825            (3, 111, 451, 487, 488, 523)       6
# 825             826               (307, 443, 470, 723, 973)       5
# 826             827      (26, 238, 402, 570, 628, 705, 961)       7
# 827             828            (3, 111, 451, 487, 488, 523)       6
#
# [828 rows x 3 columns]

# %%
res_df = fpgrowth(df, min_support=0.1)
# Out:
# <generator object fpg_step at 0x112ec5200>

# %%
association_rules(res_df)
# Out:
#     antecedents  consequents  antecedent support  consequent support  \
# 0          (18)         (21)            0.190821            0.212560
# 1          (21)         (18)            0.212560            0.190821
# 2          (50)         (21)            0.158213            0.212560
# 3      (50, 18)         (21)            0.123188            0.212560
# 4          (50)         (37)            0.158213            0.141304
# ..          ...          ...                 ...                 ...
# 753     (1, 27)      (32, 9)            0.126812            0.124396
# 754      (1, 9)     (32, 27)            0.119565            0.138889
# 755     (9, 27)      (32, 1)            0.121981            0.126812
# 756         (1)  (32, 9, 27)            0.129227            0.120773
# 757        (27)   (32, 1, 9)            0.141304            0.118357
#
#       support  confidence      lift
# 0    0.172705    0.905063  4.257911
# 1    0.172705    0.812500  4.257911
# 2    0.143720    0.908397  4.273595
# 3    0.113527    0.921569  4.335561
# 4    0.132850    0.839695  5.942454
# ..        ...         ...       ...
# 753  0.115942    0.914286  7.349792
# 754  0.115942    0.969697  6.981818
# 755  0.115942    0.950495  7.495332
# 756  0.115942    0.897196  7.428785
# 757  0.115942    0.820513  6.932496
#
# [758 rows x 7 columns]
